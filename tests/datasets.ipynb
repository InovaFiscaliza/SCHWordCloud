# %%
import schwordcloud
from pathlib import Path

# %%
cloud_annotation_file = Path(r'D:\Users\maxwelfreitas\ANATEL\InovaFiscaliza - DataHub - GET\SCH\Annotation.xlsx')
local_annotation_folder = r'E:\datasets\sch\annotation'
df = schwordcloud.fetch_annotation(cloud_annotation_file,local_annotation_folder)
df
# Out:
#                                          ID             DataHora  \
# 0      001f8c9b-c83f-488c-8bd4-fe92909a51ec  08/08/2024 11:31:59
# 1      00225394-f4a7-4e96-8c33-d84dafefa1ac  06/10/2024 11:30:28
# 2      002562da-097d-4f53-ae34-6ae6f92e9b48  24/09/2024 11:33:24
# 3      003c2c5c-7823-41b8-978b-85c3f859d7cf  16/11/2024 15:00:42
# 4      004631d8-85b5-4dad-b6de-5a7c8bd29659  30/10/2024 05:00:22
# ...                                     ...                  ...
# 10783  accfabfd-4973-4c6f-b9a5-d9aadfb43c09  17/04/2025 04:00:29
# 10784  a590d771-e1a2-4683-b015-f00b795f41d1  17/04/2025 05:00:29
# 10785  4be01796-8642-469b-88e5-1e5172ed5471  17/04/2025 05:00:33
# 10786  e1a89b06-5806-41cc-a3b6-a17e4933d70b  17/04/2025 05:00:36
# 10787  30b7361a-270b-4dda-9136-58f0f21b18cc  17/04/2025 05:00:38
#
#            Computador               Usuário     Homologação   Atributo  \
# 0        ES6927559DTL         maxwelfreitas  03685-11-05967  WordCloud
# ...

# %%
local_sch_folder = r'E:\datasets\sch\sch'
df = schwordcloud.fetch_sch_database(local_sch_folder)
df
# Out:
#        Data da Homologação Número de Homologação  \
# 0               2025-04-03          041141303428
# 1               2025-04-03          041141303428
# 2               2015-01-23          044571407864
# 3               2015-01-23          044571407864
# 4               2017-09-21          037411102482
# ...                    ...                   ...
# 160195          2018-11-01          060401810095
# 160196          2022-01-11          087001701086
# 160197          2022-01-11          087001701086
# 160198          2022-01-11          087001701086
# 160199          2022-01-11          087001701086
#
#                                       Nome do Solicitante CNPJ do Solicitante  \
# 0                         CommScope Cabos do Brasil Ltda.      03759340000601
# 1                         CommScope Cabos do Brasil Ltda.      03759340000601
# 2                                      SouthPartner Ltda.      04296807000174
# ...
